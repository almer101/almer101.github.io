# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
plt.style.use('bmh')

# %%
N = 1000
B = 1
dt = 1/N
sigma = 1

w = [0]

while w[-1] < B:
    dw = sigma * np.sqrt(dt) * np.random.normal(0,1)
    w.append(w[-1] + dw)

ts = np.linspace(0, dt * (len(w)-1), len(w))
plt.plot(ts, w)

# %%
def simulate_BM(dt, B):
    max_iter = 10000
    w = [0]
    while w[-1] < B:
        dw = sigma * np.sqrt(dt) * np.random.normal(0,1)
        w.append(w[-1] + dw)
        if len(w) > max_iter:
            return ([0],[0])

    ts = np.linspace(0, dt * (len(w)-1), len(w))
    return (ts, w)

# %%
max_t = 0
sum_t = 0
cnt = 0
for i in tqdm(range(1000)):
    ts, w = simulate_BM(dt, B=B)
    if len(ts) == 1: continue
    sum_t += ts[-1]
    cnt += 1
    # plt.plot(ts,w)
    max_t = max(max_t, ts[-1])

# plt.plot([0,max_t+1], [B, B], label=f'B={B}')
# plt.xlim((0,max_t+1))
# plt.legend()

print(sum_t/cnt)
# Out:
#   0%|                                                          | 0/1000 [00:00<?, ?it/s]
#   3%|█▍                                              | 31/1000 [00:00<00:03, 285.32it/s]
#   6%|██▉                                             | 60/1000 [00:00<00:03, 270.89it/s]
#   9%|████▏                                           | 88/1000 [00:00<00:03, 240.27it/s]
#  11%|█████▎                                         | 113/1000 [00:00<00:03, 228.44it/s]
#  14%|██████▍                                        | 137/1000 [00:00<00:03, 219.00it/s]
#  16%|███████▋                                       | 163/1000 [00:00<00:03, 226.99it/s]
#  20%|█████████▎                                     | 197/1000 [00:00<00:03, 257.95it/s]
#  23%|██████████▌                                    | 226/1000 [00:00<00:02, 263.45it/s]
#  26%|████████████                                   | 257/1000 [00:01<00:02, 276.40it/s]
#  28%|█████████████▍                                 | 285/1000 [00:01<00:02, 277.26it/s]
#  31%|██████████████▋                                | 313/1000 [00:01<00:02, 268.74it/s]
#  34%|████████████████                               | 341/1000 [00:01<00:02, 261.32it/s]
#  37%|█████████████████▎                             | 368/1000 [00:01<00:02, 240.54it/s]
#  39%|██████████████████▍                            | 393/1000 [00:01<00:02, 221.33it/s]
#  42%|███████████████████▌                           | 417/1000 [00:01<00:02, 224.87it/s]
#  44%|████████████████████▋                          | 440/1000 [00:01<00:02, 224.02it/s]
#  47%|██████████████████████▏                        | 472/1000 [00:01<00:02, 249.92it/s]
#  50%|███████████████████████▍                       | 499/1000 [00:02<00:01, 253.42it/s]
#  53%|████████████████████████▉                      | 531/1000 [00:02<00:01, 271.37it/s]
#  56%|██████████████████████████▎                    | 559/1000 [00:02<00:01, 256.23it/s]
#  58%|███████████████████████████▍                   | 585/1000 [00:02<00:01, 232.59it/s]
#  61%|████████████████████████████▌                  | 609/1000 [00:02<00:01, 234.47it/s]
#  64%|██████████████████████████████▏                | 641/1000 [00:02<00:01, 253.52it/s]
#  67%|███████████████████████████████▎               | 667/1000 [00:02<00:01, 246.43it/s]
#  69%|████████████████████████████████▌              | 692/1000 [00:02<00:01, 242.20it/s]
#  72%|█████████████████████████████████▋             | 718/1000 [00:02<00:01, 247.00it/s]
#  74%|██████████████████████████████████▉            | 744/1000 [00:03<00:01, 246.28it/s]
#  78%|████████████████████████████████████▌          | 779/1000 [00:03<00:00, 269.89it/s]
#  81%|█████████████████████████████████████▉         | 807/1000 [00:03<00:00, 262.91it/s]
#  83%|███████████████████████████████████████▏       | 834/1000 [00:03<00:00, 249.06it/s]
#  86%|████████████████████████████████████████▍      | 860/1000 [00:03<00:00, 240.15it/s]
#  89%|█████████████████████████████████████████▋     | 887/1000 [00:03<00:00, 242.54it/s]
#  92%|███████████████████████████████████████████    | 916/1000 [00:03<00:00, 254.89it/s]
#  94%|████████████████████████████████████████████▎  | 942/1000 [00:03<00:00, 247.26it/s]
#  97%|█████████████████████████████████████████████▍ | 967/1000 [00:03<00:00, 246.99it/s]
# 100%|██████████████████████████████████████████████▉| 998/1000 [00:04<00:00, 261.25it/s]
# 100%|██████████████████████████████████████████████| 1000/1000 [00:04<00:00, 249.32it/s]
# 2.246094612352171
