# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
plt.style.use('bmh')

# %%
N = 1000
B = 1
dt = 1/N
sigma = 1

w = [0]

while w[-1] < B:
    dw = sigma * np.sqrt(dt) * np.random.normal(0,1)
    w.append(w[-1] + dw)

ts = np.linspace(0, dt * (len(w)-1), len(w))
plt.plot(ts, w)

# %%
def simulate_BM(dt, B):
    max_iter = 10000
    w = [0]
    while w[-1] < B:
        dw = sigma * np.sqrt(dt) * np.random.normal(0,1)
        w.append(w[-1] + dw)
        if len(w) > max_iter:
            return ([0],[0])

    ts = np.linspace(0, dt * (len(w)-1), len(w))
    return (ts, w)

# %%
max_t = 0
sum_t = 0
cnt = 0
for i in tqdm(range(1000)):
    ts, w = simulate_BM(dt, B=B)
    if len(ts) == 1: continue
    sum_t += ts[-1]
    cnt += 1
    # plt.plot(ts,w)
    max_t = max(max_t, ts[-1])

# plt.plot([0,max_t+1], [B, B], label=f'B={B}')
# plt.xlim((0,max_t+1))
# plt.legend()

print(sum_t/cnt)
# Out:
#   0%|                                                            | 0/1000 [00:00<?, ?it/s]
#   2%|█                                                 | 20/1000 [00:00<00:04, 196.81it/s]
#   4%|██                                                | 40/1000 [00:00<00:04, 197.99it/s]
#   6%|███                                               | 60/1000 [00:00<00:05, 185.14it/s]
#   8%|████▏                                             | 84/1000 [00:00<00:04, 205.13it/s]
#  10%|█████▏                                           | 105/1000 [00:00<00:04, 203.73it/s]
#  13%|██████▎                                          | 128/1000 [00:00<00:04, 211.33it/s]
#  16%|███████▋                                         | 157/1000 [00:00<00:03, 233.65it/s]
#  19%|█████████▎                                       | 189/1000 [00:00<00:03, 252.81it/s]
#  22%|██████████▌                                      | 215/1000 [00:00<00:03, 252.97it/s]
#  24%|███████████▊                                     | 242/1000 [00:01<00:02, 254.84it/s]
#  27%|█████████████▏                                   | 268/1000 [00:01<00:02, 251.36it/s]
#  29%|██████████████▍                                  | 294/1000 [00:01<00:03, 233.39it/s]
#  32%|███████████████▊                                 | 323/1000 [00:01<00:02, 243.25it/s]
#  35%|█████████████████                                | 348/1000 [00:01<00:02, 242.18it/s]
#  38%|██████████████████▊                              | 384/1000 [00:01<00:02, 272.39it/s]
#  42%|████████████████████▌                            | 420/1000 [00:01<00:01, 294.74it/s]
#  45%|██████████████████████                           | 450/1000 [00:01<00:01, 283.21it/s]
#  48%|███████████████████████▌                         | 482/1000 [00:01<00:01, 288.65it/s]
#  51%|█████████████████████████                        | 512/1000 [00:02<00:01, 273.00it/s]
#  54%|██████████████████████████▍                      | 540/1000 [00:02<00:01, 269.01it/s]
#  57%|███████████████████████████▊                     | 568/1000 [00:02<00:01, 257.49it/s]
#  60%|█████████████████████████████▏                   | 596/1000 [00:02<00:01, 263.56it/s]
#  62%|██████████████████████████████▌                  | 623/1000 [00:02<00:01, 247.94it/s]
#  65%|███████████████████████████████▊                 | 649/1000 [00:02<00:01, 236.09it/s]
#  68%|█████████████████████████████████                | 675/1000 [00:02<00:01, 240.53it/s]
#  70%|██████████████████████████████████▎              | 700/1000 [00:02<00:01, 230.13it/s]
#  72%|███████████████████████████████████▍             | 724/1000 [00:02<00:01, 217.98it/s]
#  75%|████████████████████████████████████▌            | 747/1000 [00:03<00:01, 218.77it/s]
#  77%|█████████████████████████████████████▋           | 770/1000 [00:03<00:01, 208.90it/s]
#  80%|███████████████████████████████████████          | 798/1000 [00:03<00:00, 227.88it/s]
#  83%|████████████████████████████████████████▍        | 826/1000 [00:03<00:00, 238.38it/s]
#  85%|█████████████████████████████████████████▋       | 851/1000 [00:03<00:00, 227.07it/s]
#  88%|███████████████████████████████████████████      | 880/1000 [00:03<00:00, 244.21it/s]
#  90%|████████████████████████████████████████████▎    | 905/1000 [00:03<00:00, 235.62it/s]
#  93%|█████████████████████████████████████████████▌   | 929/1000 [00:03<00:00, 235.78it/s]
#  95%|██████████████████████████████████████████████▋  | 954/1000 [00:03<00:00, 236.05it/s]
#  98%|████████████████████████████████████████████████▏| 983/1000 [00:04<00:00, 248.69it/s]
# 100%|████████████████████████████████████████████████| 1000/1000 [00:04<00:00, 242.17it/s]
# 2.293956464379947
