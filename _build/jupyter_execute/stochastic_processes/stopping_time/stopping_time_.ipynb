# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
plt.style.use('bmh')

# %%
N = 1000
B = 1
dt = 1/N
sigma = 1

w = [0]

while w[-1] < B:
    dw = sigma * np.sqrt(dt) * np.random.normal(0,1)
    w.append(w[-1] + dw)

ts = np.linspace(0, dt * (len(w)-1), len(w))
plt.plot(ts, w)

# %%
def simulate_BM(dt, B):
    max_iter = 10000
    w = [0]
    while w[-1] < B:
        dw = sigma * np.sqrt(dt) * np.random.normal(0,1)
        w.append(w[-1] + dw)
        if len(w) > max_iter:
            return ([0],[0])

    ts = np.linspace(0, dt * (len(w)-1), len(w))
    return (ts, w)

# %%
max_t = 0
sum_t = 0
cnt = 0
for i in tqdm(range(1000)):
    ts, w = simulate_BM(dt, B=B)
    if len(ts) == 1: continue
    sum_t += ts[-1]
    cnt += 1
    # plt.plot(ts,w)
    max_t = max(max_t, ts[-1])

# plt.plot([0,max_t+1], [B, B], label=f'B={B}')
# plt.xlim((0,max_t+1))
# plt.legend()

print(sum_t/cnt)
# Out:
#   0%|                                                                | 0/1000 [00:00<?, ?it/s]
#   3%|█▋                                                    | 31/1000 [00:00<00:03, 298.53it/s]
#   6%|███▎                                                  | 61/1000 [00:00<00:03, 271.16it/s]
#   9%|████▊                                                 | 89/1000 [00:00<00:03, 244.21it/s]
#  11%|██████                                               | 114/1000 [00:00<00:03, 223.21it/s]
#  14%|███████▍                                             | 140/1000 [00:00<00:03, 232.96it/s]
#  17%|█████████                                            | 172/1000 [00:00<00:03, 255.18it/s]
#  20%|██████████▌                                          | 199/1000 [00:00<00:03, 253.29it/s]
#  23%|████████████                                         | 228/1000 [00:00<00:02, 263.57it/s]
#  26%|█████████████▌                                       | 257/1000 [00:00<00:02, 270.23it/s]
#  28%|███████████████                                      | 285/1000 [00:01<00:02, 272.17it/s]
#  31%|████████████████▌                                    | 313/1000 [00:01<00:02, 259.88it/s]
#  34%|██████████████████                                   | 340/1000 [00:01<00:02, 251.75it/s]
#  37%|███████████████████▍                                 | 366/1000 [00:01<00:02, 223.47it/s]
#  39%|████████████████████▌                                | 389/1000 [00:01<00:02, 224.22it/s]
#  41%|█████████████████████▊                               | 412/1000 [00:01<00:02, 221.52it/s]
#  44%|███████████████████████                              | 435/1000 [00:01<00:02, 209.30it/s]
#  46%|████████████████████████▏                            | 457/1000 [00:01<00:02, 204.39it/s]
#  48%|█████████████████████████▋                           | 484/1000 [00:02<00:02, 217.89it/s]
#  51%|██████████████████████████▊                          | 507/1000 [00:02<00:02, 218.49it/s]
#  54%|████████████████████████████▍                        | 536/1000 [00:02<00:01, 234.55it/s]
#  56%|█████████████████████████████▋                       | 560/1000 [00:02<00:01, 234.37it/s]
#  59%|███████████████████████████████                      | 587/1000 [00:02<00:01, 238.24it/s]
#  61%|████████████████████████████████▍                    | 611/1000 [00:02<00:01, 235.91it/s]
#  64%|██████████████████████████████████▏                  | 645/1000 [00:02<00:01, 260.54it/s]
#  68%|████████████████████████████████████▏                | 682/1000 [00:02<00:01, 285.98it/s]
#  71%|█████████████████████████████████████▋               | 711/1000 [00:02<00:01, 270.08it/s]
#  74%|███████████████████████████████████████▏             | 739/1000 [00:03<00:01, 249.96it/s]
#  76%|████████████████████████████████████████▌            | 765/1000 [00:03<00:00, 241.37it/s]
#  79%|█████████████████████████████████████████▊           | 790/1000 [00:03<00:00, 239.77it/s]
#  82%|███████████████████████████████████████████▎         | 818/1000 [00:03<00:00, 250.67it/s]
#  84%|████████████████████████████████████████████▋        | 844/1000 [00:03<00:00, 237.98it/s]
#  87%|██████████████████████████████████████████████       | 869/1000 [00:03<00:00, 221.81it/s]
#  89%|███████████████████████████████████████████████▎     | 892/1000 [00:03<00:00, 213.92it/s]
#  91%|████████████████████████████████████████████████▍    | 914/1000 [00:03<00:00, 209.13it/s]
#  94%|█████████████████████████████████████████████████▌   | 936/1000 [00:03<00:00, 211.27it/s]
#  96%|██████████████████████████████████████████████████▊  | 958/1000 [00:04<00:00, 209.20it/s]
#  98%|███████████████████████████████████████████████████▉ | 979/1000 [00:04<00:00, 207.01it/s]
# 100%|████████████████████████████████████████████████████| 1000/1000 [00:04<00:00, 202.84it/s]
# 100%|████████████████████████████████████████████████████| 1000/1000 [00:04<00:00, 234.48it/s]
# 2.199614555256065
